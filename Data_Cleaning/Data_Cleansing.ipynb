# %%
import pandas as pd
import numpy as np
import re
import nltk
import string
import datetime
import json
from datetime import date
from nltk.corpus import stopwords

# %%
#columns of the csv file
COLS = ['id', 'created_at', 'text']

# %%
tweets = []
for line in open("twitter_data.txt","r"):
    tweets.append(json.loads(line))
# Out:
# [{'created_at': 'Fri May 08 10:47:23 +0000 2020', 'hashtags': [], 'id': 1258710079722799106, 'id_str': '1258710079722799106', 'lang': 'en', 'media': [{'display_url': 'pic.twitter.com/YcKJQhcELI', 'expanded_url': 'https://twitter.com/NHM_JHARKHAND/status/1258710079722799106/photo/1', 'id': 1258709763451310080, 'media_url': 'http://pbs.twimg.com/media/EXfV3GXU0AAlGmj.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EXfV3GXU0AAlGmj.jpg', 'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1314}, 'medium': {'h': 1200, 'resize': 'fit', 'w': 770}, 'small': {'h': 680, 'resize': 'fit', 'w': 436}, 'thumb': {'h': 150, 'resize': 'crop', 'w': 150}}, 'type': 'photo', 'url': 'https://t.co/YcKJQhcELI'}], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'text': 'COVID-19 https://t.co/YcKJQhcELI', 'urls': [], 'user': {'created_at': 'Tue Sep 02 17:02:34 +0000 2014', 'default_profile': True, 'description': 'National Health Mission, Government of Jharkhand', 'favourites_count': 18, 'followers_count': 1317, 'friends_count': 255, 'geo_enabled': True, 'id': 2786292492, 'id_str': '2786292492', 'listed_count': 9, 'location': 'Ranchi, Jharkhand, India', 'name': 'NHM Jharkhand', 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2786292492/1587457655', 'profile_image_url': 'http://pbs.twimg.com/profile_images/507945497609265152/I_Kbee9a_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/507945497609265152/I_Kbee9a_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'screen_name': 'NHM_JHARKHAND', 'statuses_count': 495, 'url': 'http://t.co/ZzGoNznQ1u'}, 'user_mentions': []}, {'created_at': 'Fri May 08 10:47:23 +0000 2020', 'hashtags': [], 'id': 1258710079676784641, 'id_str': '1258710079676784641', 'in_reply_to_screen_name': 'KamenGamerRetro', 'in_reply_to_status_id': 1258573276739186689, 'in_reply_to_user_id': 3555611233, 'lang': 'en', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'text': '@KamenGamerRetro @anxiety_4_dayz @RSpurs1980 @DanaSchwartzzz I’d also like to point out that the current health cri… https://t.co/XTLSiS3JHe', 'truncated': True, 'urls': [{'expanded_url': 'https://twitter.com/i/web/status/1258710079676784641', 'url': 'https://t.co/XTLSiS3JHe'}], 'user': {'created_at': 'Sun Nov 20 15:18:27 +0000 2011', 'default_profile': True, 'favourites_count': 29324, 'followers_count': 100, 'friends_count': 543, 'geo_enabled': True, 'id': 417125834, 'id_str': '417125834', 'listed_count': 1, 'name': 'Dan', 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_image_url': 'http://pbs.twimg.com/profile_images/3609455467/57ada78d7335a4f98b090279d7fb5b9b_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3609455467/57ada78d7335a4f98b090279d7fb5b9b_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'screen_name': 'baxter_daniel', 'statuses_count': 8968}, 'user_mentions': [{'id': 3555611233, 'id_str': '3555611233', 'name': 'Kamengamerretro', 'screen_name': 'KamenGamerRetro'}, {'id': 9998182, 'id_str': '9998182', 'name': "Mitt Romney's other secret account", 'screen_name': 'anxiety_4_dayz'}, {'id': 1218882834347237376, 'id_str': '1218882834347237376', 'name': 'RSpurs1980(“Don’t get your hopes up.”Levy 2020)', 'screen_name': 'RSpurs1980'}, {'i ...

# %%
RDB = {}
for var in COLS:
    Text = []
    for i in range(0,len(tweets)):
        Text.append(tweets[i][var])
    RDB[var]=Text

# %%
#Emoji patterns
emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"
         "]+", flags=re.UNICODE)

# %%
##Cleaning & Convert Twitter Data to dataframe

def TwitterCleaning(DB):
    
    HDB = pd.DataFrame(DB)
    
    #Converting Datetime
    HDB['created_at'] = pd.to_datetime(HDB['created_at'])

    #Cleaning HTML Tags
    HDB['text']=HDB['text'].apply(lambda x: re.sub('<[^>]*>','',x))

    #Cleaning URL link
    HDB['text']=HDB['text'].apply(lambda x: re.sub(r"http\S+", "", x))

    #Cleaning punctuations
    HDB['text']=HDB['text'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

    #lower Case
    HDB['text']=HDB['text'].apply(lambda x: x.lower())
    
    #Remove Emoji
    HDB['text']=HDB['text'].apply(lambda x: emoji_pattern.sub(r'',x))
   
    return HDB

# %%
FDB = TwitterCleaning(RDB)

# %%
FDB.to_csv("Cleaned_Twitter_Data.csv")

# %%
df = pd.read_csv('covid-19_20200508.csv')
df.head()
# Out:
#    Unnamed: 0        Date        Location Confirmed  \
# 0           0  2020-05-08       Worldwide   3845607
# 1           1  2020-05-08   United States   1289235
# 2           2  2020-05-08           Spain    221447
# 3           3  2020-05-08           Italy    215858
# 4           4  2020-05-08  United Kingdom    206715
#
#   Cases per 1 million people Recovered  Deaths
# 0                        495   1282930  269564
# 1                       3912    174697   76537
# 2                       4702    128511   26070
# 3                       3583     96276   29958
# 4                       3112         —   30615

# %%
missing_values = ["n/a", "na", "—"]
df = pd.read_csv("data/covid-19_20200508.csv", na_values = missing_values)

print (df.isnull().sum())
# Out:
# Unnamed: 0                     0
# Date                           0
# Location                       0
# Confirmed                      2
# Cases per 1 million people     7
# Recovered                     18
# Deaths                         5
# dtype: int64

# %%
df['Confirmed'] = df['Confirmed'].fillna(0).astype(int)
df['Cases per 1 million people'] = df['Cases per 1 million people'].fillna(0).astype(int)
df['Recovered'] = df['Recovered'].fillna(0).astype(int)
df['Deaths'] = df['Deaths'].fillna(0).astype(int)

print (df.isnull().sum())
# Out:
# Unnamed: 0                    0
# Date                          0
# Location                      0
# Confirmed                     0
# Cases per 1 million people    0
# Recovered                     0
# Deaths                        0
# dtype: int64

# %%
df.head()
df.to_csv("Cleaned_Covid_Data.csv")
# Out:
#    Unnamed: 0        Date        Location  Confirmed  \
# 0           0  2020-05-08       Worldwide    3845607
# 1           1  2020-05-08   United States    1289235
# 2           2  2020-05-08           Spain     221447
# 3           3  2020-05-08           Italy     215858
# 4           4  2020-05-08  United Kingdom     206715
#
#    Cases per 1 million people  Recovered  Deaths
# 0                         495    1282930  269564
# 1                        3912     174697   76537
# 2                        4702     128511   26070
# 3                        3583      96276   29958
# 4                        3112          0   30615
